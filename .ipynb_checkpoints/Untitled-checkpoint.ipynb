# %%
from bs4 import BeautifulSoup

html_doc = open('sample-data.html', 'r')

soup = BeautifulSoup(html_doc, 'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<html>\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type">\n   <meta content="Report generated by Flip Side Racing Software www.flipsideracing.org" name="description">\n    <style type="text/css">\n     p {\n\t\t  \n\t\t  background-color: white;\n\t\t  color: black;\n\t\t  font-family: "Trebuchet MS",Verdana,Arial,Helvetica,sans-serif;\n\t\t  font-size: 12px;\n\t\t  font-weight: normal;\n\t\t  padding-left: 1em;\n\t\t  padding-right: 1em;\n\t\t}\n\t\ttd {\n\t\t  \n\t\t  background-color: white;\n\t\t  color: black;\n\t\t  font-family: "Trebuchet MS",Verdana,Arial,Helvetica,sans-serif;\n\t\t  font-size: 12px;\n\t\t  font-weight: normal;\n\t\t  padding-left: 1em;\n\t\t  padding-right: 1em;\n\t\t}\n\t\tth {\n\t\t  \n\t\t  color: black;\n\t\t  font-family: "Trebuchet MS",Verdana,Arial,Helvetica,sans-serif;\n\t\t  font-size: 12px;\n\t\t  padding-left: 1em;\
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#    <meta content="Report generated by Flip Side Racing Software www.flipsideracing.org" name="description">
#     <style type="text/css">
#      p {
#
# 		  background-color: white;
# 		  color: black;
# 		  font-family: "Trebuchet MS",Verdana,Arial,Helvetica,sans-serif;
# 		  font-size: 12px;
# 		  font-weight: normal;
# 		  padding-left: 1em;
# 		  padding-right: 1em;
# 		}
# 		td {
#
# 		  background-color: white;
# 		  color: black;
# 		  font-family: "Trebuchet MS",Verdana,Arial,Helvetica,sans-serif;
# 		  font-size: 12px;
# 		  font-weight: normal;
# 		  padding-left: 1em;
# 		  padding-right: 1em;
# 		}
# 		th {
#
# 		  color: black;
# 		  font-family: "Trebuchet MS",Verdana,Arial,Helvetica,sans-serif;
# 		  font-size: 12px;
# 		  padding-left: 1em;
# 		  padding-right: 1em;
# ...

# %%
soup.title
# Out:
# <title>Race Results</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# 'Race Results'

# %%
soup.title.parent.name
# Out:
# 'meta'

# %%
soup.a

# %%
soup.table
# Out:
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody align="right">
# <tr>
# <td align="center" colspan="7"><img alt="Club logo" src="exampleLogo.jpg"/></td>
# </tr>
# <tr class="ttd">
# <td align="center" colspan="7">Power Racing Series</td>
# </tr>
# <tr>
# <td align="center" colspan="7">2017 New York Sprint 2 Main 2017-09-23 15:07:22</td>
# </tr>
# <tr>
# <td align="center" colspan="7">Lap</td>
# </tr>
# <tr>
# <td align="center" colspan="7">Main</td>
# </tr>
# <tr>
# <td>
# <br>
# </br></td>
# </tr>
# </tbody>
# </table>

# %%
soup.find_all('table')
# Out:
# [<table border="0" cellpadding="0" cellspacing="0" width="100%">
#  <tbody align="right">
#  <tr>
#  <td align="center" colspan="7"><img alt="Club logo" src="exampleLogo.jpg"/></td>
#  </tr>
#  <tr class="ttd">
#  <td align="center" colspan="7">Power Racing Series</td>
#  </tr>
#  <tr>
#  <td align="center" colspan="7">2017 New York Sprint 2 Main 2017-09-23 15:07:22</td>
#  </tr>
#  <tr>
#  <td align="center" colspan="7">Lap</td>
#  </tr>
#  <tr>
#  <td align="center" colspan="7">Main</td>
#  </tr>
#  <tr>
#  <td>
#  <br>
#  </br></td>
#  </tr>
#  </tbody>
#  </table>, <table border="0" cellpadding="0" cellspacing="0" width="100%">
#  <thead align="right" class="hth">
#  <tr>
#  <th>Position</th>
#  <th>Laps</th>
#  <th>Time</th>
#  <th>Average</th>
#  <th>Best</th>
#  <th>Laps Leading</th>
#  <th>Name</th>
#  </tr>
#  </thead>
#  <tbody align="right">
#  <tr>
#  <td>1</td>
#  <td>30</td>
#  <td>11:20.014</td>
#  <td>22.667</td>
#  <td>30/19.501</td>
#  <td>11</td>
# ...

# %%
for table in soup.find_all('table'):
    print(table)
# Out:
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody align="right">
# <tr>
# <td align="center" colspan="7"><img alt="Club logo" src="exampleLogo.jpg"/></td>
# </tr>
# <tr class="ttd">
# <td align="center" colspan="7">Power Racing Series</td>
# </tr>
# <tr>
# <td align="center" colspan="7">2017 New York Sprint 2 Main 2017-09-23 15:07:22</td>
# </tr>
# <tr>
# <td align="center" colspan="7">Lap</td>
# </tr>
# <tr>
# <td align="center" colspan="7">Main</td>
# </tr>
# <tr>
# <td>
# <br>
# </br></td>
# </tr>
# </tbody>
# </table>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <thead align="right" class="hth">
# <tr>
# <th>Position</th>
# <th>Laps</th>
# <th>Time</th>
# <th>Average</th>
# <th>Best</th>
# <th>Laps Leading</th>
# <th>Name</th>
# </tr>
# </thead>
# <tbody align="right">
# <tr>
# <td>1</td>
# <td>30</td>
# <td>11:20.014</td>
# <td>22.667</td>
# <td>30/19.501</td>
# <td>11</td>
# <td>Atomic Chibi</td>
# </tr>
# <tr class="gtd">
# ...

# %%
soup.find_all('table')[0]
# Out:
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody align="right">
# <tr>
# <td align="center" colspan="7"><img alt="Club logo" src="exampleLogo.jpg"/></td>
# </tr>
# <tr class="ttd">
# <td align="center" colspan="7">Power Racing Series</td>
# </tr>
# <tr>
# <td align="center" colspan="7">2017 New York Sprint 2 Main 2017-09-23 15:07:22</td>
# </tr>
# <tr>
# <td align="center" colspan="7">Lap</td>
# </tr>
# <tr>
# <td align="center" colspan="7">Main</td>
# </tr>
# <tr>
# <td>
# <br>
# </br></td>
# </tr>
# </tbody>
# </table>

# %%
soup.find_all('table')[1]
# Out:
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <thead align="right" class="hth">
# <tr>
# <th>Position</th>
# <th>Laps</th>
# <th>Time</th>
# <th>Average</th>
# <th>Best</th>
# <th>Laps Leading</th>
# <th>Name</th>
# </tr>
# </thead>
# <tbody align="right">
# <tr>
# <td>1</td>
# <td>30</td>
# <td>11:20.014</td>
# <td>22.667</td>
# <td>30/19.501</td>
# <td>11</td>
# <td>Atomic Chibi</td>
# </tr>
# <tr class="gtd">
# <td>2</td>
# <td>30</td>
# <td>11:22.749</td>
# <td>22.758</td>
# <td>29/19.084</td>
# <td>8</td>
# <td>Lego Car</td>
# </tr>
# <tr>
# <td>3</td>
# <td>30</td>
# <td>11:36.034</td>
# <td>23.201</td>
# <td>2/19.707</td>
# <td>0</td>
# <td>RU Greasy</td>
# </tr>
# <tr class="gtd">
# <td>4</td>
# <td>28</td>
# <td>11:29.735</td>
# <td>24.633</td>
# <td>17/21.990</td>
# <td>0</td>
# <td>The Bus</td>
# </tr>
# <tr>
# <td>5</td>
# <td>28</td>
# <td>11:34.684</td>
# <td>24.81</td>
# <td>23/22.117</td>
# <td>0</td>
# <td>Amazon Box</td>
# </tr>
# ...

# %%
results = soup.find_all('table')[1]

# %%
print(results)
# Out:
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <thead align="right" class="hth">
# <tr>
# <th>Position</th>
# <th>Laps</th>
# <th>Time</th>
# <th>Average</th>
# <th>Best</th>
# <th>Laps Leading</th>
# <th>Name</th>
# </tr>
# </thead>
# <tbody align="right">
# <tr>
# <td>1</td>
# <td>30</td>
# <td>11:20.014</td>
# <td>22.667</td>
# <td>30/19.501</td>
# <td>11</td>
# <td>Atomic Chibi</td>
# </tr>
# <tr class="gtd">
# <td>2</td>
# <td>30</td>
# <td>11:22.749</td>
# <td>22.758</td>
# <td>29/19.084</td>
# <td>8</td>
# <td>Lego Car</td>
# </tr>
# <tr>
# <td>3</td>
# <td>30</td>
# <td>11:36.034</td>
# <td>23.201</td>
# <td>2/19.707</td>
# <td>0</td>
# <td>RU Greasy</td>
# </tr>
# <tr class="gtd">
# <td>4</td>
# <td>28</td>
# <td>11:29.735</td>
# <td>24.633</td>
# <td>17/21.990</td>
# <td>0</td>
# <td>The Bus</td>
# </tr>
# <tr>
# <td>5</td>
# <td>28</td>
# <td>11:34.684</td>
# <td>24.81</td>
# <td>23/22.117</td>
# <td>0</td>
# <td>Amazon Box</td>
# </tr>
# ...

# %%
for child in soup.find_all('table')[1].descendants:
    print(child)
# Out:
# <thead align="right" class="hth">
# <tr>
# <th>Position</th>
# <th>Laps</th>
# <th>Time</th>
# <th>Average</th>
# <th>Best</th>
# <th>Laps Leading</th>
# <th>Name</th>
# </tr>
# </thead>
#
#
# <tr>
# <th>Position</th>
# <th>Laps</th>
# <th>Time</th>
# <th>Average</th>
# <th>Best</th>
# <th>Laps Leading</th>
# <th>Name</th>
# </tr>
#
#
# <th>Position</th>
# Position
#
#
# <th>Laps</th>
# Laps
#
#
# <th>Time</th>
# Time
#
#
# <th>Average</th>
# Average
#
#
# <th>Best</th>
# Best
#
#
# <th>Laps Leading</th>
# Laps Leading
#
#
# <th>Name</th>
# Name
#
#
#
#
#
#
# <tbody align="right">
# <tr>
# <td>1</td>
# <td>30</td>
# <td>11:20.014</td>
# <td>22.667</td>
# <td>30/19.501</td>
# <td>11</td>
# <td>Atomic Chibi</td>
# </tr>
# <tr class="gtd">
# <td>2</td>
# <td>30</td>
# <td>11:22.749</td>
# <td>22.758</td>
# <td>29/19.084</td>
# <td>8</td>
# <td>Lego Car</td>
# </tr>
# <tr>
# <td>3</td>
# <td>30</td>
# <td>11:36.034</td>
# <td>23.201</td>
# <td>2/19.707</td>
# <td>0</td>
# ...

# %%
result_soup = BeautifulSoup(str(results), 'html.parser')

# %%
print(result_soup.prettify())
# Out:
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
#  <thead align="right" class="hth">
#   <tr>
#    <th>
#     Position
#    </th>
#    <th>
#     Laps
#    </th>
#    <th>
#     Time
#    </th>
#    <th>
#     Average
#    </th>
#    <th>
#     Best
#    </th>
#    <th>
#     Laps Leading
#    </th>
#    <th>
#     Name
#    </th>
#   </tr>
#  </thead>
#  <tbody align="right">
#   <tr>
#    <td>
#     1
#    </td>
#    <td>
#     30
#    </td>
#    <td>
#     11:20.014
#    </td>
#    <td>
#     22.667
#    </td>
#    <td>
#     30/19.501
#    </td>
#    <td>
#     11
#    </td>
#    <td>
#     Atomic Chibi
#    </td>
#   </tr>
#   <tr class="gtd">
#    <td>
#     2
#    </td>
#    <td>
#     30
#    </td>
#    <td>
#     11:22.749
#    </td>
#    <td>
#     22.758
#    </td>
#    <td>
#     29/19.084
#    </td>
#    <td>
#     8
#    </td>
#    <td>
#     Lego Car
#    </td>
#   </tr>
#   <tr>
#    <td>
#     3
#    </td>
#    <td>
#     30
#    </td>
#    <td>
# ...

# %%
print(result_soup.contents)
# Out:
# [<table border="0" cellpadding="0" cellspacing="0" width="100%">
# <thead align="right" class="hth">
# <tr>
# <th>Position</th>
# <th>Laps</th>
# <th>Time</th>
# <th>Average</th>
# <th>Best</th>
# <th>Laps Leading</th>
# <th>Name</th>
# </tr>
# </thead>
# <tbody align="right">
# <tr>
# <td>1</td>
# <td>30</td>
# <td>11:20.014</td>
# <td>22.667</td>
# <td>30/19.501</td>
# <td>11</td>
# <td>Atomic Chibi</td>
# </tr>
# <tr class="gtd">
# <td>2</td>
# <td>30</td>
# <td>11:22.749</td>
# <td>22.758</td>
# <td>29/19.084</td>
# <td>8</td>
# <td>Lego Car</td>
# </tr>
# <tr>
# <td>3</td>
# <td>30</td>
# <td>11:36.034</td>
# <td>23.201</td>
# <td>2/19.707</td>
# <td>0</td>
# <td>RU Greasy</td>
# </tr>
# <tr class="gtd">
# <td>4</td>
# <td>28</td>
# <td>11:29.735</td>
# <td>24.633</td>
# <td>17/21.990</td>
# <td>0</td>
# <td>The Bus</td>
# </tr>
# <tr>
# <td>5</td>
# <td>28</td>
# <td>11:34.684</td>
# <td>24.81</td>
# <td>23/22.117</td>
# <td>0</td>
# <td>Amazon Box</td>
# </tr>
# ...

# %%
for child in result_soup.children:
    print(child)
# Out:
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <thead align="right" class="hth">
# <tr>
# <th>Position</th>
# <th>Laps</th>
# <th>Time</th>
# <th>Average</th>
# <th>Best</th>
# <th>Laps Leading</th>
# <th>Name</th>
# </tr>
# </thead>
# <tbody align="right">
# <tr>
# <td>1</td>
# <td>30</td>
# <td>11:20.014</td>
# <td>22.667</td>
# <td>30/19.501</td>
# <td>11</td>
# <td>Atomic Chibi</td>
# </tr>
# <tr class="gtd">
# <td>2</td>
# <td>30</td>
# <td>11:22.749</td>
# <td>22.758</td>
# <td>29/19.084</td>
# <td>8</td>
# <td>Lego Car</td>
# </tr>
# <tr>
# <td>3</td>
# <td>30</td>
# <td>11:36.034</td>
# <td>23.201</td>
# <td>2/19.707</td>
# <td>0</td>
# <td>RU Greasy</td>
# </tr>
# <tr class="gtd">
# <td>4</td>
# <td>28</td>
# <td>11:29.735</td>
# <td>24.633</td>
# <td>17/21.990</td>
# <td>0</td>
# <td>The Bus</td>
# </tr>
# <tr>
# <td>5</td>
# <td>28</td>
# <td>11:34.684</td>
# <td>24.81</td>
# <td>23/22.117</td>
# <td>0</td>
# <td>Amazon Box</td>
# </tr>
# ...

# %%
results.find_all('tr')
# Out:
# [<tr>
#  <th>Position</th>
#  <th>Laps</th>
#  <th>Time</th>
#  <th>Average</th>
#  <th>Best</th>
#  <th>Laps Leading</th>
#  <th>Name</th>
#  </tr>, <tr>
#  <td>1</td>
#  <td>30</td>
#  <td>11:20.014</td>
#  <td>22.667</td>
#  <td>30/19.501</td>
#  <td>11</td>
#  <td>Atomic Chibi</td>
#  </tr>, <tr class="gtd">
#  <td>2</td>
#  <td>30</td>
#  <td>11:22.749</td>
#  <td>22.758</td>
#  <td>29/19.084</td>
#  <td>8</td>
#  <td>Lego Car</td>
#  </tr>, <tr>
#  <td>3</td>
#  <td>30</td>
#  <td>11:36.034</td>
#  <td>23.201</td>
#  <td>2/19.707</td>
#  <td>0</td>
#  <td>RU Greasy</td>
#  </tr>, <tr class="gtd">
#  <td>4</td>
#  <td>28</td>
#  <td>11:29.735</td>
#  <td>24.633</td>
#  <td>17/21.990</td>
#  <td>0</td>
#  <td>The Bus</td>
#  </tr>, <tr>
#  <td>5</td>
#  <td>28</td>
#  <td>11:34.684</td>
#  <td>24.81</td>
#  <td>23/22.117</td>
#  <td>0</td>
#  <td>Amazon Box</td>
#  </tr>, <tr class="gtd">
#  <td>6</td>
#  <td>27</td>
#  <td>11:36.440</td>
#  <td>25.794</td>
#  <td>10/22.462</td>
# ...

# %%
results.find_all('tr')[0]
# Out:
# <tr>
# <th>Position</th>
# <th>Laps</th>
# <th>Time</th>
# <th>Average</th>
# <th>Best</th>
# <th>Laps Leading</th>
# <th>Name</th>
# </tr>

# %%
len(results.find_all('tr'))
# Out:
# 19

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Panel4D',
#  'Period',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseList',
#  'SparsePanel',
#  'SparseSeries',
#  'SparseTimeSeries',
#  'Term',
#  'TimeGrouper',
#  'TimeSeries',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'WidePanel',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_np_version_under1p10',
#  '_np_version_under1p11',
#  '_np_version_under1p12',
#  '_np_version_under1p8',
#  '_np_version_under1p9',
#  '_period',
#  '_sparse',
#  '_testing',
#  '_version',
#  'algos',
#  'bdate_range',
# ...

# %%
header = results.find_all('tr')[0]

# %%
for item in header.children:
    print(item.string)
# Out:
# Position
#
#
# Laps
#
#
# Time
#
#
# Average
#
#
# Best
#
#
# Laps Leading
#
#
# Name

# %%
header = [item.string for item in results.find_all('tr')[0] if item.string != '\n']

# %%
print(header)
# Out:
# ['Position', 'Laps', 'Time', 'Average', 'Best', 'Laps Leading', 'Name']

# %%
for row in results.find_all('tr'):
    clean_row = [item.string for item in row if item.string != '\n']
    print(clean_row)
# Out:
# ['Position', 'Laps', 'Time', 'Average', 'Best', 'Laps Leading', 'Name']
# ['1', '30', '11:20.014', '22.667', '30/19.501', '11', 'Atomic Chibi']
# ['2', '30', '11:22.749', '22.758', '29/19.084', '8', 'Lego Car']
# ['3', '30', '11:36.034', '23.201', '2/19.707', '0', 'RU Greasy']
# ['4', '28', '11:29.735', '24.633', '17/21.990', '0', 'The Bus']
# ['5', '28', '11:34.684', '24.81', '23/22.117', '0', 'Amazon Box']
# ['6', '27', '11:36.440', '25.794', '10/22.462', '0', 'Blue Meanie']
# ['7', '27', '11:39.702', '25.915', '15/19.236', '2', 'Electric Koolaid Acid Test']
# ['8', '22', '11:26.011', '31.182', '4/26.520', '0', 'MAV 721']
# ['9', '21', '11:35.918', '33.139', '14/31.678', '0', 'Smoothie']
# ['10', '20', '11:43.065', '35.153', '13/30.852', '0', 'Maximum Overdrive']
# ['11', '19', '11:34.858', '36.571', '18/20.315', '0', 'FUBAR']
# ['12', '16', '8:15.778', '30.986', '9/25.756', '0', 'Aerobot']
# ['13', '15', '11:36.035', '46.402', '7/28.310', '0', 'Train Wrecks']
# ...
